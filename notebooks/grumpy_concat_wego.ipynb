# %%
import pandas as pd
import seaborn as sns

# %%
headway_data=pd.read_csv('../data/Headway Data.csv')

# %%
headway_data
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 2          120211101             1      76447166  2021-11-01           7
# 3          120211101             1      76447167  2021-11-01          50
# 4          120211101             1      76447168  2021-11-01          50
# ...              ...           ...           ...         ...         ...
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
bna_2022=pd.read_csv('../data/bna_2022.csv')

# %%
bna_2022
# Out:
#        key        class  expire_time_gmt obs_id   obs_name  valid_time_gmt  \
# 0     KBNA  observation       1641027180   KBNA  Nashville      1641019980
# 1     KBNA  observation       1641030780   KBNA  Nashville      1641023580
# 2     KBNA  observation       1641034380   KBNA  Nashville      1641027180
# 3     KBNA  observation       1641037980   KBNA  Nashville      1641030780
# 4     KBNA  observation       1641041580   KBNA  Nashville      1641034380
# ...    ...          ...              ...    ...        ...             ...
# 7775  KBNA  observation       1646106780   KBNA  Nashville      1646099580
# 7776  KBNA  observation       1646110380   KBNA  Nashville      1646103180
# 7777  KBNA  observation       1646113980   KBNA  Nashville      1646106780
# 7778  KBNA  observation       1646117580   KBNA  Nashville      1646110380
# 7779  KBNA  observation       1646121180   KBNA  Nashville      1646113980
#
#      day_ind  temp  wx_icon  icon_extd  ... clds  water_temp  \
# ...

# %%
bna_weather=pd.read_csv('../data/bna_weather.csv')

# %%
bna_weather
# Out:
#                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# ...

# %%
bna_2022.shape
# Out:
# (7780, 45)

# %%
bna_weather.shape
# Out:
# (9739, 46)

# %%
import matplotlib.pyplot as plt

# %%
headway_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1981715 entries, 0 to 1981714
# Data columns (total 30 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   CALENDAR_ID                int64
#  1   SERVICE_ABBR               int64
#  2   ADHERENCE_ID               int64
#  3   DATE                       object
#  4   ROUTE_ABBR                 int64
#  5   BLOCK_ABBR                 int64
#  6   OPERATOR                   int64
#  7   TRIP_ID                    int64
#  8   OVERLOAD_ID                int64
#  9   ROUTE_DIRECTION_NAME       object
#  10  TIME_POINT_ABBR            object
#  11  ROUTE_STOP_SEQUENCE        float64
#  12  TRIP_EDGE                  int64
#  13  LATITUDE                   float64
#  14  LONGITUDE                  float64
#  15  SCHEDULED_TIME             object
#  16  ACTUAL_ARRIVAL_TIME        object
#  17  ACTUAL_DEPARTURE_TIME      object
#  18  ADHERENCE                  float64
# ...

# %%
bna_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9739 entries, 0 to 9738
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       9739 non-null   object
#  1   key                        9739 non-null   object
#  2   class                      9739 non-null   object
#  3   expire_time_gmt            9739 non-null   int64
#  4   obs_id                     9739 non-null   object
#  5   obs_name                   9739 non-null   object
#  6   valid_time_gmt             9739 non-null   int64
#  7   day_ind                    9739 non-null   object
#  8   temp                       9739 non-null   int64
#  9   wx_icon                    9739 non-null   int64
#  10  icon_extd                  9739 non-null   int64
#  11  wx_phrase                  9739 non-null   object
#  12  pressure_tend              2885 non-null   float64
# ...

# %%
headway_data.isna().sum()
# Out:
# CALENDAR_ID                       0
# SERVICE_ABBR                      0
# ADHERENCE_ID                      0
# DATE                              0
# ROUTE_ABBR                        0
# BLOCK_ABBR                        0
# OPERATOR                          0
# TRIP_ID                           0
# OVERLOAD_ID                       0
# ROUTE_DIRECTION_NAME              0
# TIME_POINT_ABBR                   0
# ROUTE_STOP_SEQUENCE              41
# TRIP_EDGE                         0
# LATITUDE                          0
# LONGITUDE                         0
# SCHEDULED_TIME                    0
# ACTUAL_ARRIVAL_TIME           54383
# ACTUAL_DEPARTURE_TIME         54430
# ADHERENCE                     54430
# SCHEDULED_HDWY               432294
# ACTUAL_HDWY                  473824
# HDWY_DEV                     474368
# ADJUSTED_EARLY_COUNT              0
# ADJUSTED_LATE_COUNT               0
# ADJUSTED_ONTIME_COUNT             0
# STOP_CANCELLED                    0
# ...

# %%
bna_weather['wx_icon'].value_counts()
# Out:
# 33    1923
# 28    1565
# 26    1558
# 34    1242
# 30     961
# 27     827
# 29     559
# 11     418
# 4      162
# 12     129
# 20     123
# 14      68
# 40      47
# 38      41
# 47      26
# 7       20
# 42      19
# 9       17
# 21      14
# 16      13
# 22       4
# 18       3
# Name: wx_icon, dtype: int64

# %%
headway_data['ROUTE_ABBR'].value_counts()
# Out:
# 55    362259
# 56    355098
# 52    291150
# 23    250787
# 50    249880
# 3     216446
# 22    153074
# 7     103021
# Name: ROUTE_ABBR, dtype: int64

# %%
headway_data['OPERATOR'].value_counts()
# Out:
# 1147    15479
# 1587    15352
# 664     15268
# 409     14889
# 1020    14495
#         ...
# 2091        1
# 2219        1
# 242         1
# 315         1
# 2310        1
# Name: OPERATOR, Length: 458, dtype: int64

# %%
bna_weather.columns
# Out:
# Index(['Date', 'key', 'class', 'expire_time_gmt', 'obs_id', 'obs_name',
#        'valid_time_gmt', 'day_ind', 'temp', 'wx_icon', 'icon_extd',
#        'wx_phrase', 'pressure_tend', 'pressure_desc', 'dewPt', 'heat_index',
#        'rh', 'pressure', 'vis', 'wc', 'wdir', 'wdir_cardinal', 'gust', 'wspd',
#        'max_temp', 'min_temp', 'precip_total', 'precip_hrly', 'snow_hrly',
#        'uv_desc', 'feels_like', 'uv_index', 'qualifier', 'qualifier_svrty',
#        'blunt_phrase', 'terse_phrase', 'clds', 'water_temp',
#        'primary_wave_period', 'primary_wave_height', 'primary_swell_period',
#        'primary_swell_height', 'primary_swell_direction',
#        'secondary_swell_period', 'secondary_swell_height',
#        'secondary_swell_direction'],
#       dtype='object')

# %%
print(bna_weather)
# Out:
#                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# ...

# %%
a = headway_data.loc[(headway_data['CALENDAR_ID'] == 120211101) & (headway_data['ROUTE_ABBR'] == 7)]
a
# Out:
#       CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0       120211101             1      76447164  2021-11-01           7
# 1       120211101             1      76447165  2021-11-01           7
# 2       120211101             1      76447166  2021-11-01           7
# 1647    120211101             1      76450453  2021-11-01           7
# 1648    120211101             1      76450454  2021-11-01           7
# ...           ...           ...           ...         ...         ...
# 5903    120211101             1      76455665  2021-11-01           7
# 5904    120211101             1      76455666  2021-11-01           7
# 5905    120211101             1      76455667  2021-11-01           7
# 5906    120211101             1      76455668  2021-11-01           7
# 5907    120211101             1      76455669  2021-11-01           7
#
#       BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
bna_weather.isna().sum()
# Out:
# Date                            0
# key                             0
# class                           0
# expire_time_gmt                 0
# obs_id                          0
# obs_name                        0
# valid_time_gmt                  0
# day_ind                         0
# temp                            0
# wx_icon                         0
# icon_extd                       0
# wx_phrase                       0
# pressure_tend                6854
# pressure_desc                6854
# dewPt                           0
# heat_index                      0
# rh                              0
# pressure                        0
# vis                             4
# wc                              8
# wdir                         1522
# wdir_cardinal                   8
# gust                         8279
# wspd                            8
# max_temp                     9378
# min_temp                     9378
# precip_total                 9636
# ...

# %%
bna_weather=bna_weather.drop(columns=['qualifier','qualifier_svrty','blunt_phrase','terse_phrase','water_temp','primary_wave_period','primary_wave_height','primary_swell_period','primary_swell_height','primary_swell_direction','secondary_swell_period','secondary_swell_height','secondary_swell_direction'])

# %%
bna_weather.isna().sum()
# Out:
# Date                  0
# key                   0
# class                 0
# expire_time_gmt       0
# obs_id                0
# obs_name              0
# valid_time_gmt        0
# day_ind               0
# temp                  0
# wx_icon               0
# icon_extd             0
# wx_phrase             0
# pressure_tend      6854
# pressure_desc      6854
# dewPt                 0
# heat_index            0
# rh                    0
# pressure              0
# vis                   4
# wc                    8
# wdir               1522
# wdir_cardinal         8
# gust               8279
# wspd                  8
# max_temp           9378
# min_temp           9378
# precip_total       9636
# precip_hrly           0
# snow_hrly          9730
# uv_desc              14
# feels_like            1
# uv_index             14
# clds                  0
# dtype: int64

# %%
bna_weather
# Out:
#                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  wspd max_temp  \
# ...

# %%
bna_weather=bna_weather.drop(columns=['max_temp','min_temp','precip_total','snow_hrly'])

# %%
bna_weather
# Out:
#                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...    wc   wdir  \
# ...

# %%
headway_data['ROUTE_STOP_SEQUENCE'].value_counts()
# Out:
# 5.0     278419
# 4.0     214527
# 8.0     181918
# 3.0     177798
# 2.0     157335
# 10.0    154766
# 6.0     153988
# 9.0     141764
# 7.0     102499
# 11.0     99828
# 12.0     73821
# 13.0     63406
# 14.0     52909
# 15.0     46339
# 1.0      32748
# 17.0     24805
# 16.0     24804
# Name: ROUTE_STOP_SEQUENCE, dtype: int64

# %%
headway_data['ROUTE_ABBR'].value_counts()
# Out:
# 55    362259
# 56    355098
# 52    291150
# 23    250787
# 50    249880
# 3     216446
# 22    153074
# 7     103021
# Name: ROUTE_ABBR, dtype: int64

# %% [markdown]
# ### Avg of 5.5 stops per route...

# %%
headway_data['ROUTE_ABBR'].sum()/headway_data['ROUTE_STOP_SEQUENCE'].sum()
# Out:
# 5.522900805545507

# %%
drivers_per_day=headway_data['OPERATOR'].sum()/headway_data['CALENDAR_ID']
drivers_per_day
# Out:
# 0          26.957589
# 1          26.957589
# 2          26.957589
# 3          26.957589
# 4          26.957589
#              ...
# 1981710    26.955346
# 1981711    26.955346
# 1981712    26.955346
# 1981713    26.955346
# 1981714    26.955346
# Name: CALENDAR_ID, Length: 1981715, dtype: float64

# %%
#operator_headway=headway_data.loc[headway_data['OPERATOR']]&headway_data[headway_data[('ROUTE_ABBR')]]
#operator_headway

# %% [markdown]
# # How closely does lateness (ADHERENCE) correlate to headway?

# %%
def unique(operator):
    unique_operator= []
    for i in operator:
        if i not in unique_operator:
            unique_operator.append(i)
    for i in unique_operator:
        print (i),
        
operator = headway_data['OPERATOR']
unique(operator)
# Out:
# 2088
# 1352
# 1194
# 1652
# 1206
# 1386
# 1300
# 1222
# 1762
# 1733
# 785
# 366
# 1383
# 1277
# 1394
# 1807
# 306
# 1462
# 1823
# 1147
# 2253
# 1763
# 409
# 1927
# 725
# 1307
# 2322
# 2368
# 1611
# 2207
# 1208
# 2349
# 471
# 1020
# 1984
# 1379
# 907
# 1578
# 1782
# 1796
# 1904
# 2312
# 664
# 1838
# 1293
# 2208
# 310
# 1305
# 2041
# 446
# 1650
# 1493
# 2000
# 1280
# 1419
# 2027
# 1390
# 2371
# 572
# 1052
# 719
# 1214
# 2062
# 1198
# 2119
# 2126
# 332
# 2055
# 1542
# 1036
# 639
# 1505
# 2311
# 1359
# 1597
# 2102
# 2178
# 1716
# 1603
# 557
# 1788
# 778
# 329
# 1251
# 1815
# 1228
# 2151
# 1158
# 1202
# 2221
# 2109
# 2217
# 1743
# 1814
# 465
# 2035
# 2306
# 2098
# 2294
# 1749
# 1489
# 1330
# 1997
# 1271
# 2289
# 2012
# 1730
# 1268
# 1842
# 1175
# 2053
# 357
# 1540
# 2399
# 1361
# 611
# 375
# 2400
# 1704
# 1780
# 1211
# 1177
# 1866
# 359
# 2138
# 2137
# 2112
# 723
# 1410
# 1133
# 2410
# 2247
# 2164
# 2186
# 2421
# 2059
# 1880
# 1391
# 2040
# 2347
# 1256
# 1382
# 653
# 2439
# 1401
# 1617
# ...

# %%
import numpy as np

# %%
headway_data.plot(kind='scatter',x='ADHERENCE', y='HDWY_DEV', figsize=(14,10))
# Out:
# <AxesSubplot:xlabel='ADHERENCE', ylabel='HDWY_DEV'>

# %%
late_bus=headway_data[headway_data['HDWY_DEV']>0]
early_bus=headway_data[headway_data['HDWY_DEV']<0]
on_time=headway_data[headway_data['HDWY_DEV']==0]

# %%
early_depart=headway_data[headway_data['ADHERENCE']>0]
late_depart=headway_data[headway_data['ADHERENCE']<0]
on_time_depart=headway_data[headway_data['ADHERENCE']==0]

# %%
late_depart
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 2          120211101             1      76447166  2021-11-01           7
# 3          120211101             1      76447167  2021-11-01          50
# 6          120211101             1      76447970  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981703    120221101             1      91057348  2022-11-01          22
# 1981705    120221101             1      91057372  2022-11-01          50
# 1981706    120221101             1      91057373  2022-11-01          50
# 1981709    120221101             1      91057723  2022-11-01          50
# 1981710    120221101             1      91057724  2022-11-01          50
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
late_bus
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 13         120211101             1      76447977  2021-11-01          22
# 16         120211101             1      76447980  2021-11-01          22
# 17         120211101             1      76447981  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981686    120221101             1      91056020  2022-11-01           7
# 1981687    120221101             1      91056021  2022-11-01           7
# 1981689    120221101             1      91056025  2022-11-01           7
# 1981690    120221101             1      91056026  2022-11-01           7
# 1981692    120221101             1      91056028  2022-11-01           7
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
late_bus.plot(kind='scatter',x='HDWY_DEV', y='ADHERENCE', figsize=(14,10))
plt.show()

# %%
early_bus
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 12         120211101             1      76447976  2021-11-01          22
# 14         120211101             1      76447978  2021-11-01          22
# 24         120211101             1      76447988  2021-11-01          22
# 27         120211101             1      76447991  2021-11-01          22
# 34         120211101             1      76447998  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981695    120221101             1      91056031  2022-11-01           7
# 1981696    120221101             1      91056032  2022-11-01           7
# 1981698    120221101             1      91056034  2022-11-01           7
# 1981699    120221101             1      91056035  2022-11-01           7
# 1981711    120221101             1      91057851  2022-11-01          50
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
on_time
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 257        120211101             1      76448225  2021-11-01          22
# 572        120211101             1      76448548  2021-11-01          23
# 758        120211101             1      76448740  2021-11-01          23
# 1048       120211101             1      76449034  2021-11-01          23
# 1681       120211101             1      76450638  2021-11-01          50
# ...              ...           ...           ...         ...         ...
# 1978933    120221101             1      91052828  2022-11-01          52
# 1979110    120221101             1      91053011  2022-11-01          55
# 1979402    120221101             1      91053309  2022-11-01          55
# 1980759    120221101             1      91054704  2022-11-01          56
# 1980788    120221101             1      91054733  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
headway_data['ADHERENCE'].corr(headway_data['ACTUAL_HDWY'])
# Out:
# -0.08644095025323129

# %%
early_bus.plot(kind='scatter',y='ADHERENCE', x='HDWY_DEV', figsize=(14,10))
plt.show()

# %%
on_time.plot(kind='scatter',x='ADHERENCE', y='HDWY_DEV', figsize=(14,10))
# Out:
# <AxesSubplot:xlabel='ADHERENCE', ylabel='HDWY_DEV'>

# %%
headway_data.isna().sum()
# Out:
# CALENDAR_ID                       0
# SERVICE_ABBR                      0
# ADHERENCE_ID                      0
# DATE                              0
# ROUTE_ABBR                        0
# BLOCK_ABBR                        0
# OPERATOR                          0
# TRIP_ID                           0
# OVERLOAD_ID                       0
# ROUTE_DIRECTION_NAME              0
# TIME_POINT_ABBR                   0
# ROUTE_STOP_SEQUENCE              41
# TRIP_EDGE                         0
# LATITUDE                          0
# LONGITUDE                         0
# SCHEDULED_TIME                    0
# ACTUAL_ARRIVAL_TIME           54383
# ACTUAL_DEPARTURE_TIME         54430
# ADHERENCE                     54430
# SCHEDULED_HDWY               432294
# ACTUAL_HDWY                  473824
# HDWY_DEV                     474368
# ADJUSTED_EARLY_COUNT              0
# ADJUSTED_LATE_COUNT               0
# ADJUSTED_ONTIME_COUNT             0
# STOP_CANCELLED                    0
# ...

# %%
early_depart_clean=early_depart.dropna()
early_depart_clean
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 27         120211101             1      76447991  2021-11-01          22
# 45         120211101             1      76448009  2021-11-01          22
# 46         120211101             1      76448010  2021-11-01          22
# 53         120211101             1      76448017  2021-11-01          22
# 54         120211101             1      76448018  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981678    120221101             1      91056012  2022-11-01           7
# 1981683    120221101             1      91056017  2022-11-01           7
# 1981684    120221101             1      91056018  2022-11-01           7
# 1981689    120221101             1      91056025  2022-11-01           7
# 1981711    120221101             1      91057851  2022-11-01          50
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
late_depart_clean=late_depart.dropna()
late_depart_clean
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 12         120211101             1      76447976  2021-11-01          22
# 13         120211101             1      76447977  2021-11-01          22
# 14         120211101             1      76447978  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981693    120221101             1      91056029  2022-11-01           7
# 1981695    120221101             1      91056031  2022-11-01           7
# 1981696    120221101             1      91056032  2022-11-01           7
# 1981698    120221101             1      91056034  2022-11-01           7
# 1981699    120221101             1      91056035  2022-11-01           7
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
on_time_depart_clean=on_time_depart.dropna()
on_time_depart_clean
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 71         120211101             1      76448035  2021-11-01          22
# 465        120211101             1      76448437  2021-11-01          22
# 615        120211101             1      76448591  2021-11-01          23
# 1110       120211101             1      76449096  2021-11-01          23
# 1387       120211101             1      76449713  2021-11-01           3
# ...              ...           ...           ...         ...         ...
# 1979240    120221101             1      91053143  2022-11-01          55
# 1980332    120221101             1      91054269  2022-11-01          56
# 1980690    120221101             1      91054633  2022-11-01          56
# 1981096    120221101             1      91055047  2022-11-01          56
# 1981287    120221101             1      91055242  2022-11-01          56
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
fig=plt.figure()

for frame in [late_bus,late_depart_clean]:
    plt.plot( frame['ADHERENCE'],frame['HDWY_DEV'] )
    
plt.show()

# %%
ax = late_bus.plot(x='ADHERENCE', y='HDWY_DEV')
late_depart_clean(ax=ax, x='ADHERENCE', y='HDWY_DEV')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       1 ax = late_bus.plot(x='ADHERENCE', y='HDWY_DEV')
# ----> 2 late_depart_clean(ax=ax, x='ADHERENCE', y='HDWY_DEV')
#       3 plt.show()
#
# TypeError: 'DataFrame' object is not callable

# %%
df=pd.concat([late_bus,late_depart_clean]).reset_index(drop=True)
fig, ax=plt.subplots(figsize=(14,10))
sns.scatterplot(ax=ax,data=df, x = 'ADHERENCE', y= 'HDWY_DEV', palette = ['red','blue'])
# Out:
# <AxesSubplot:xlabel='ADHERENCE', ylabel='HDWY_DEV'>

# %%
df=pd.concat([late_bus,on_time_depart_clean]).reset_index(drop=True)
fig, ax=plt.subplots(figsize=(14,10))
sns.scatterplot(ax=ax,data=df, x = 'ADHERENCE', y= 'HDWY_DEV', hue="ROUTE_ABBR", style='ROUTE_DIRECTION_NAME')
# Out:
# <AxesSubplot:xlabel='ADHERENCE', ylabel='HDWY_DEV'>

# %%
df=pd.concat([late_bus,early_depart_clean]).reset_index(drop=True)
fig, ax=plt.subplots(figsize=(14,10))
sns.scatterplot(ax=ax,data=df, y = 'ADHERENCE', x= 'HDWY_DEV')
# Out:
# <AxesSubplot:xlabel='HDWY_DEV', ylabel='ADHERENCE'>
