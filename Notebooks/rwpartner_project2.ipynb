# %% [markdown]
# # EDA

# %% [markdown]
# Step 1) import packages
#
# Why are there more rows in bna_weather compared to bna_2022.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 2) Download CSV files into python

# %%
weather = pd.read_csv('../Data/bna_weather.csv')

# %%
headway = pd.read_csv('../Data/Headway Data.csv')

# %%
# don't need bna_20222. weather = pd.read_csv('../Data/bna_2022.csv')

# %% [markdown]
# Step 3) Shape, head, dtypes (columns), info

# %%
weather.shape
# Out:
# (9739, 46)

# %%
headway.shape
# Out:
# (1981715, 30)

# %%
weather.info
# Out:
# <bound method DataFrame.info of                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# ...

# %%
headway.info
# Out:
# <bound method DataFrame.info of          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 2          120211101             1      76447166  2021-11-01           7
# 3          120211101             1      76447167  2021-11-01          50
# 4          120211101             1      76447168  2021-11-01          50
# ...              ...           ...           ...         ...         ...
# 1981710    120221101             1      91057724  2022-11-01          50
# 1981711    120221101             1      91057851  2022-11-01          50
# 1981712    120221101             1      91057852  2022-11-01          50
# 1981713    120221101             1      91057881  2022-11-01          56
# 1981714    120221101             1      91057882  2022-11-01          56
#
# ...

# %%
weather
# Out:
#                      Date   key        class  expire_time_gmt obs_id  \
# 0     2021-11-01 00:53:00  KBNA  observation       1635753180   KBNA
# 1     2021-11-01 01:30:00  KBNA  observation       1635755400   KBNA
# 2     2021-11-01 01:53:00  KBNA  observation       1635756780   KBNA
# 3     2021-11-01 02:53:00  KBNA  observation       1635760380   KBNA
# 4     2021-11-01 03:53:00  KBNA  observation       1635763980   KBNA
# ...                   ...   ...          ...              ...    ...
# 9734  2022-10-31 19:53:00  KBNA  observation       1667271180   KBNA
# 9735  2022-10-31 20:53:00  KBNA  observation       1667274780   KBNA
# 9736  2022-10-31 21:53:00  KBNA  observation       1667278380   KBNA
# 9737  2022-10-31 22:53:00  KBNA  observation       1667281980   KBNA
# 9738  2022-10-31 23:53:00  KBNA  observation       1667285580   KBNA
#
#        obs_name  valid_time_gmt day_ind  temp  wx_icon  ...  clds water_temp  \
# ...

# %%
headway.head()
# Out:
#    CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0    120211101             1      76447164  2021-11-01           7
# 1    120211101             1      76447165  2021-11-01           7
# 2    120211101             1      76447166  2021-11-01           7
# 3    120211101             1      76447167  2021-11-01          50
# 4    120211101             1      76447168  2021-11-01          50
#
#    BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# 0        1704      2088   297750            0          TO DOWNTOWN  ...
# 1        1704      2088   297750            0          TO DOWNTOWN  ...
# 2        1704      2088   297750            0          TO DOWNTOWN  ...
# 3        1704      2088   297749            0          TO DOWNTOWN  ...
# 4        1704      2088   297749            0          TO DOWNTOWN  ...
#
#   ACTUAL_HDWY  HDWY_DEV  ADJUSTED_EARLY_COUNT  ADJUSTED_LATE_COUNT  \
# ...

# %%
weather.dtypes
# Out:
# Date                          object
# key                           object
# class                         object
# expire_time_gmt                int64
# obs_id                        object
# obs_name                      object
# valid_time_gmt                 int64
# day_ind                       object
# temp                           int64
# wx_icon                        int64
# icon_extd                      int64
# wx_phrase                     object
# pressure_tend                float64
# pressure_desc                 object
# dewPt                          int64
# heat_index                     int64
# rh                             int64
# pressure                     float64
# vis                          float64
# wc                           float64
# wdir                         float64
# wdir_cardinal                 object
# gust                         float64
# wspd                         float64
# max_temp                     float64
# ...

# %%
headway.dtypes
# Out:
# CALENDAR_ID                    int64
# SERVICE_ABBR                   int64
# ADHERENCE_ID                   int64
# DATE                          object
# ROUTE_ABBR                     int64
# BLOCK_ABBR                     int64
# OPERATOR                       int64
# TRIP_ID                        int64
# OVERLOAD_ID                    int64
# ROUTE_DIRECTION_NAME          object
# TIME_POINT_ABBR               object
# ROUTE_STOP_SEQUENCE          float64
# TRIP_EDGE                      int64
# LATITUDE                     float64
# LONGITUDE                    float64
# SCHEDULED_TIME                object
# ACTUAL_ARRIVAL_TIME           object
# ACTUAL_DEPARTURE_TIME         object
# ADHERENCE                    float64
# SCHEDULED_HDWY               float64
# ACTUAL_HDWY                  float64
# HDWY_DEV                     float64
# ADJUSTED_EARLY_COUNT           int64
# ADJUSTED_LATE_COUNT            int64
# ADJUSTED_ONTIME_COUNT          int64
# ...

# %%
headway['ROUTE_DIRECTION_NAME'].value_counts()
# Out:
# FROM DOWNTOWN    1047952
# TO DOWNTOWN       933763
# Name: ROUTE_DIRECTION_NAME, dtype: int64

# %%
headway['DATE'].value_counts()

# 336 days
# Out:
# 2022-10-26    6540
# 2022-11-01    6498
# 2022-05-02    6491
# 2022-04-06    6489
# 2022-10-06    6488
#               ...
# 2022-01-16    2994
# 2021-11-25    2993
# 2021-12-24    2990
# 2022-03-27    2989
# 2021-12-26    2987
# Name: DATE, Length: 366, dtype: int64

# %%
headway['TIME_POINT_ABBR'].value_counts()

# 65 different time point abbreviations
# Out:
# GXRVRGAT    88506
# DWMRT       83826
# WHBG        67522
# MXTHOMP     60462
# MXWHARF     60447
#             ...
# CRES          170
# HLHS          137
# MCC4_13       131
# MCC5_3         85
# MCC4_21         5
# Name: TIME_POINT_ABBR, Length: 65, dtype: int64

# %%
# pd.DataFrame(people_df['sex'].value_counts(dropna = False))

pd.DataFrame(headway['HDWY_DEV'].value_counts())
# Out:
#             HDWY_DEV
#  0.000000       5276
# -0.100000       4636
# -0.033334       4592
# -0.016667       4590
#  0.033333       4554
# ...              ...
#  69.483333         1
#  63.666666         1
#  46.433333         1
#  45.300000         1
# -27.633334         1
#
# [6019 rows x 1 columns]

# %%
headway.describe()
# Out:
#         CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID    ROUTE_ABBR    BLOCK_ABBR  \
# count  1.981715e+06  1.981715e+06  1.981715e+06  1.981715e+06  1.981715e+06
# mean   1.202191e+08  1.301276e+00  8.440206e+07  3.933449e+01  3.947508e+03
# std    3.423559e+03  6.398457e-01  4.330643e+06  1.969928e+01  1.973956e+03
# min    1.202111e+08  1.000000e+00  7.644716e+07  3.000000e+00  3.000000e+02
# 25%    1.202202e+08  1.000000e+00  8.075122e+07  2.300000e+01  2.301000e+03
# 50%    1.202205e+08  1.000000e+00  8.470092e+07  5.200000e+01  5.200000e+03
# 75%    1.202208e+08  1.000000e+00  8.828194e+07  5.500000e+01  5.506000e+03
# max    1.202211e+08  3.000000e+00  9.109076e+07  5.600000e+01  9.975000e+03
#
#            OPERATOR       TRIP_ID   OVERLOAD_ID  ROUTE_STOP_SEQUENCE  \
# count  1.981715e+06  1.981715e+06  1.981715e+06         1.981674e+06
# mean   1.635251e+03  3.111437e+05  9.984281e-03         7.122218e+00
# std    6.375643e+02  7.312918e+03  1.291578e-01         3.828157e+00
# ...

# %%
headway['HDWY_DEV'].describe()
# Out:
# count    1.507347e+06
# mean     3.647395e-01
# std      6.579797e+00
# min     -2.220667e+02
# 25%     -1.883334e+00
# 50%      0.000000e+00
# 75%      1.966666e+00
# max      1.054617e+03
# Name: HDWY_DEV, dtype: float64

# %%
# people_df.weight.value_counts()#.sort_index()

value_counts = headway['HDWY_DEV'].value_counts()

# %%
headway['HDWY_DEV'].mean()
# Out:
# 0.3647395373397392

# %%
# people_df.loc[:, 'years_played_sports'].sort_values()

range = [0-10]

headway_one = headway.loc[headway['HDWY_DEV'].isin([0,2])]

#new_df2004 =new_df4.loc[new_df4['Year'].isin([2004])]
# print(new_df2004)

# %%
headway_one
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 257        120211101             1      76448225  2021-11-01          22
# 350        120211101             1      76448320  2021-11-01          22
# 572        120211101             1      76448548  2021-11-01          23
# 758        120211101             1      76448740  2021-11-01          23
# 1048       120211101             1      76449034  2021-11-01          23
# ...              ...           ...           ...         ...         ...
# 1979659    120221101             1      91053570  2022-11-01          55
# 1980759    120221101             1      91054704  2022-11-01          56
# 1980788    120221101             1      91054733  2022-11-01          56
# 1980912    120221101             1      91054861  2022-11-01          56
# 1981686    120221101             1      91056020  2022-11-01           7
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
headway_one = headway.loc[headway['HDWY_DEV']>0]
headway_one
# Out:
#          CALENDAR_ID  SERVICE_ABBR  ADHERENCE_ID        DATE  ROUTE_ABBR  \
# 0          120211101             1      76447164  2021-11-01           7
# 1          120211101             1      76447165  2021-11-01           7
# 13         120211101             1      76447977  2021-11-01          22
# 16         120211101             1      76447980  2021-11-01          22
# 17         120211101             1      76447981  2021-11-01          22
# ...              ...           ...           ...         ...         ...
# 1981686    120221101             1      91056020  2022-11-01           7
# 1981687    120221101             1      91056021  2022-11-01           7
# 1981689    120221101             1      91056025  2022-11-01           7
# 1981690    120221101             1      91056026  2022-11-01           7
# 1981692    120221101             1      91056028  2022-11-01           7
#
#          BLOCK_ABBR  OPERATOR  TRIP_ID  OVERLOAD_ID ROUTE_DIRECTION_NAME  ...  \
# ...

# %%
hdwy_dev =headway.loc[:,'HDWY_DEV']
hdwy_dev
# Out:
# 0          1.983333
# 1          3.333333
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1981710         NaN
# 1981711   -2.366667
# 1981712         NaN
# 1981713         NaN
# 1981714         NaN
# Name: HDWY_DEV, Length: 1981715, dtype: float64

# %%
headway.dtypes
# Out:
# CALENDAR_ID                    int64
# SERVICE_ABBR                   int64
# ADHERENCE_ID                   int64
# DATE                          object
# ROUTE_ABBR                     int64
# BLOCK_ABBR                     int64
# OPERATOR                       int64
# TRIP_ID                        int64
# OVERLOAD_ID                    int64
# ROUTE_DIRECTION_NAME          object
# TIME_POINT_ABBR               object
# ROUTE_STOP_SEQUENCE          float64
# TRIP_EDGE                      int64
# LATITUDE                     float64
# LONGITUDE                    float64
# SCHEDULED_TIME                object
# ACTUAL_ARRIVAL_TIME           object
# ACTUAL_DEPARTURE_TIME         object
# ADHERENCE                    float64
# SCHEDULED_HDWY               float64
# ACTUAL_HDWY                  float64
# HDWY_DEV                     float64
# ADJUSTED_EARLY_COUNT           int64
# ADJUSTED_LATE_COUNT            int64
# ADJUSTED_ONTIME_COUNT          int64
# ...

# %%
#timeline_df_redo_drop=timeline_df_redo[['Child ID', 'Init. Elig. Category', 'Exit Reason']]


headway = headway[['ROUTE_ABBR','TRIP_ID','ROUTE_DIRECTION_NAME', 'SCHEDULED_HDWY', 'ACTUAL_HDWY','HDWY_DEV']]

# %%
headway
# Out:
#          ROUTE_ABBR  TRIP_ID ROUTE_DIRECTION_NAME  SCHEDULED_HDWY  \
# 0                 7   297750          TO DOWNTOWN            14.0
# 1                 7   297750          TO DOWNTOWN            14.0
# 2                 7   297750          TO DOWNTOWN             NaN
# 3                50   297749          TO DOWNTOWN             NaN
# 4                50   297749          TO DOWNTOWN             NaN
# ...             ...      ...                  ...             ...
# 1981710          50   329980          TO DOWNTOWN             NaN
# 1981711          50   330003          TO DOWNTOWN            10.0
# 1981712          50   330003          TO DOWNTOWN             NaN
# 1981713          56   330011          TO DOWNTOWN             0.0
# 1981714          56   330011          TO DOWNTOWN             NaN
#
#          ACTUAL_HDWY  HDWY_DEV
# 0          15.983333  1.983333
# 1          17.333333  3.333333
# 2                NaN       NaN
# 3                NaN       NaN
# ...

# %%
# IQR = people_desc.loc['75%', 'years_played_sports'] - people_desc.loc['25%', 'years_played_sports']

percent_headway =headway.loc['SCHEDULED_HDWY'] + headway.loc['ACTUAL_HDWY']
percent_headway
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [74], in <cell line: 3>()
#       1 # IQR = people_desc.loc['75%', 'years_played_sports'] - people_desc.loc['25%', 'years_played_sports']
# ----> 3 percent_headway =headway.loc['SCHEDULED_HDWY'] + headway.loc['ACTUAL_HDWY']
#       4 percent_headway
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# ...

# %%
percent_headway =headway['SCHEDULED_HDWY'] / headway['ACTUAL_HDWY']
print(percent_headway)
# Out:
# 0          0.875912
# 1          0.807692
# 2               NaN
# 3               NaN
# 4               NaN
#              ...
# 1981710         NaN
# 1981711    1.310044
# 1981712         NaN
# 1981713         NaN
# 1981714         NaN
# Length: 1981715, dtype: float64

# %%
percent_headway =pd.DataFrame(percent_headway)

percent_headway[0].sort_values()

# people_df.loc[:, 'years_played_sports'].sort_values()
# Out:
# 1935079    0.0
# 1895014    0.0
# 785949     0.0
# 1815136    0.0
# 1815138    0.0
#           ...
# 1981709    NaN
# 1981710    NaN
# 1981712    NaN
# 1981713    NaN
# 1981714    NaN
# Name: 0, Length: 1981715, dtype: float64

# %%
percent_headway[0].value_counts()
# Out:
# 1.000000    5276
# 1.010101    3438
# 0.990099    3307
# 1.052632    3288
# 1.020408    3203
#             ...
# 2.056555       1
# 7.860263       1
# 4.337350       1
# 6.262626       1
# 1.729622       1
# Name: 0, Length: 55074, dtype: int64

# %%
def diff(a, b):
    return b - a
  
data = np.arange(0, 20).reshape(4, 5)
  
  
df = pd.DataFrame(data,
                  index=['Row 1', 'Row 2', 'Row 3', 'Row 4'],
                  columns=['Column 1', 'Column 2', 'Column 3',
                           'Column 4', 'Column 5'])
  
  
df['Difference_2_1'] = df.apply(
    lambda x: diff(x['Column 2'], x['Column 2']), axis=1)

# %%
def div (a, b)
    return a/b

df['percent']= df.apply(
    lambda x: diff(x))
