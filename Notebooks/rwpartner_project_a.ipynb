# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
headway = pd.read_csv('../Data/Headway Data.csv')

# %%
headway_a = headway[['DATE','ROUTE_ABBR','BLOCK_ABBR','OPERATOR','TRIP_ID','ROUTE_DIRECTION_NAME','SCHEDULED_TIME', 'SCHEDULED_HDWY', 'ACTUAL_HDWY','HDWY_DEV']]

headway_a.head()
# Out:
#          DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID ROUTE_DIRECTION_NAME  \
# 0  2021-11-01           7        1704      2088   297750          TO DOWNTOWN
# 1  2021-11-01           7        1704      2088   297750          TO DOWNTOWN
# 2  2021-11-01           7        1704      2088   297750          TO DOWNTOWN
# 3  2021-11-01          50        1704      2088   297749          TO DOWNTOWN
# 4  2021-11-01          50        1704      2088   297749          TO DOWNTOWN
#
#   SCHEDULED_TIME  SCHEDULED_HDWY  ACTUAL_HDWY  HDWY_DEV
# 0     14:10:00              14.0    15.983333  1.983333
# 1     14:20:00              14.0    17.333333  3.333333
# 2     14:39:00               NaN          NaN       NaN
# 3     15:10:00               NaN          NaN       NaN
# 4     15:27:00               NaN          NaN       NaN

# %%
headway_b = headway_a[headway_a['ROUTE_ABBR']==55]
headway_b
# Out:
#                DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3320     2021-11-01          55        5500      1716   300293
# 3321     2021-11-01          55        5500      1716   300293
# 3322     2021-11-01          55        5500      1716   300293
# 3323     2021-11-01          55        5500      1716   300293
# 3324     2021-11-01          55        5500      1716   300293
# ...             ...         ...         ...       ...      ...
# 1980230  2022-11-01          55        5594      2041   328691
# 1981375  2022-11-01          55        6401      2029   329206
# 1981376  2022-11-01          55        6401      2029   329206
# 1981707  2022-11-01          55        8604      2374   329899
# 1981708  2022-11-01          55        8604      2374   329899
#
#         ROUTE_DIRECTION_NAME SCHEDULED_TIME  SCHEDULED_HDWY  ACTUAL_HDWY  \
# 3320             TO DOWNTOWN     04:22:00               NaN          NaN
# ...

# %%
headway_b=headway_a[(headway_a['ROUTE_ABBR']==55) & 
        (headway_a['DATE']=='2021-11-01')]&

# %%
headway_b.head(50)
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3320  2021-11-01          55        5500      1716   300293
# 3321  2021-11-01          55        5500      1716   300293
# 3322  2021-11-01          55        5500      1716   300293
# 3323  2021-11-01          55        5500      1716   300293
# 3324  2021-11-01          55        5500      1716   300293
# 3325  2021-11-01          55        5500      1716   300293
# 3326  2021-11-01          55        5500      1716   300286
# 3327  2021-11-01          55        5500      1716   300286
# 3328  2021-11-01          55        5500      1716   300286
# 3329  2021-11-01          55        5500      1716   300286
# 3330  2021-11-01          55        5500      1716   300286
# 3331  2021-11-01          55        5500      1716   300286
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# ...

# %%
headway_c= headway_b[headway_b['SCHEDULED_HDWY'].notnull()]
headway_c
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
# ...          ...         ...         ...       ...      ...
# 4447  2021-11-01          55        5512      1749   300663
# 4448  2021-11-01          55        5512      1749   300663
# 4449  2021-11-01          55        5512      1749   300663
# 4450  2021-11-01          55        5512      1749   300663
# 5914  2021-11-01          55        8604      2059   301624
#
#      ROUTE_DIRECTION_NAME SCHEDULED_TIME  SCHEDULED_HDWY  ACTUAL_HDWY  \
# 3332          TO DOWNTOWN     06:04:00              10.0     9.100000
# 3333          TO DOWNTOWN     06:12:00              10.0    10.600000
# ...

# %%
# calculate headway percent by dividing actual headway by scheduled headway. Over 150% is too high and under 50% is too low. 

headway_c['PERCENT'] = headway_c.ACTUAL_HDWY/headway_c.SCHEDULED_HDWY * 100
headway_c
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\645534722.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_c['PERCENT'] = headway_c.ACTUAL_HDWY/headway_c.SCHEDULED_HDWY * 100
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
# ...          ...         ...         ...       ...      ...
# 4447  2021-11-01          55        5512      1749   300663
# ...

# %%
headway_d= headway_b[
    (headway_b['SCHEDULED_HDWY'].notnull())&
    (headway_b['SCHEDULED_HDWY']!=0)
]
headway_d
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
# ...          ...         ...         ...       ...      ...
# 4446  2021-11-01          55        5512      1749   300663
# 4447  2021-11-01          55        5512      1749   300663
# 4448  2021-11-01          55        5512      1749   300663
# 4449  2021-11-01          55        5512      1749   300663
# 4450  2021-11-01          55        5512      1749   300663
#
#      ROUTE_DIRECTION_NAME SCHEDULED_TIME  SCHEDULED_HDWY  ACTUAL_HDWY  \
# 3332          TO DOWNTOWN     06:04:00              10.0     9.100000
# 3333          TO DOWNTOWN     06:12:00              10.0    10.600000
# ...

# %%
headway_d['PERCENT'] = headway_d.ACTUAL_HDWY/headway_d.SCHEDULED_HDWY * 100
headway_d
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\663218806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_d['PERCENT'] = headway_d.ACTUAL_HDWY/headway_d.SCHEDULED_HDWY * 100
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
# ...          ...         ...         ...       ...      ...
# 4446  2021-11-01          55        5512      1749   300663
# ...

# %%
too_high = headway_d[headway_d['PERCENT'] >=150]
too_high
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3396  2021-11-01          55        5500      1603   300299
# 3429  2021-11-01          55        5501       557   300341
# 3430  2021-11-01          55        5501       557   300341
# 3488  2021-11-01          55        5501      1788   300346
# 3489  2021-11-01          55        5501      1788   300346
# 3490  2021-11-01          55        5501      1788   300346
# 3657  2021-11-01          55        5503      1228   300443
# 3658  2021-11-01          55        5503      1228   300443
# 3660  2021-11-01          55        5503      1228   300437
# 3837  2021-11-01          55        5505      1202   300547
# 3843  2021-11-01          55        5505      1202   300538
# 3860  2021-11-01          55        5505      1202   300549
# 3932  2021-11-01          55        5506      2109   300586
# 3933  2021-11-01          55        5506      2109   300586
# 3957  2021-11-01          55        5506      2109   300588
# ...

# %%
too_low =  headway_d[headway_d['PERCENT'] <=50]
too_low
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3394  2021-11-01          55        5500      1603   300299
# 3395  2021-11-01          55        5500      1603   300299
# 3484  2021-11-01          55        5501      1788   300355
# 3486  2021-11-01          55        5501      1788   300346
# 3487  2021-11-01          55        5501      1788   300346
# 3559  2021-11-01          55        5502       329   300404
# 3564  2021-11-01          55        5502       329   300394
# 3565  2021-11-01          55        5502       329   300394
# 3595  2021-11-01          55        5502      1815   300399
# 3640  2021-11-01          55        5502      1419   300402
# 3654  2021-11-01          55        5503      1228   300443
# 3655  2021-11-01          55        5503      1228   300443
# 3656  2021-11-01          55        5503      1228   300443
# 3661  2021-11-01          55        5503      1228   300437
# 3662  2021-11-01          55        5503      1228   300437
# ...

# %%
df['new column name'] = df['column name'].apply
(lambda x: 'value if condition is met' 
 if x condition 
 else 'value if condition is not met')

# %%
headway_c['LOW_HIGH'] = headway_c['PERCENT'].apply
(lambda x: 'high'
if x >=150
else 'low')
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\3065742439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_c['LOW_HIGH'] = headway_c['PERCENT'].apply
# <function __main__.<lambda>(x)>

# %%
headway_c.head()
# Out:
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
#
#      ROUTE_DIRECTION_NAME SCHEDULED_TIME  SCHEDULED_HDWY  ACTUAL_HDWY  \
# 3332          TO DOWNTOWN     06:04:00              10.0     9.100000
# 3333          TO DOWNTOWN     06:12:00              10.0    10.600000
# 3334          TO DOWNTOWN     06:20:00              10.0    13.183333
# 3335          TO DOWNTOWN     06:28:00              10.0     9.716666
# 3336          TO DOWNTOWN     06:40:00              10.0    10.366666
#
#       HDWY_DEV    PERCENT LOW/HIGH  \
# 3332 -0.900000   91.00000      NaN
# 3333  0.600000  106.00000      NaN
# 3334  3.183333  131.83333      NaN
# ...

# %%
headway_d

# %%
headway_c['LOW/HIGH']=''
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\2302375940.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_c['LOW/HIGH']=''

# %%
# headway_c=del(headway_c['LOW/HIGH'])

# gdp_df.drop(gdp_df.columns[[3]], axis=1, inplace=True)

headway_c.drop(headway_c.columns[[11]],[[12]], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [75], in <cell line: 5>()
#       1 # headway_c=del(headway_c['LOW/HIGH'])
#       2
#       3 # gdp_df.drop(gdp_df.columns[[3]], axis=1, inplace=True)
# ----> 5 headway_c.drop(headway_c.columns[[11]],[[12]], axis=1, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5055, in Index.__getitem__(self, key)
#    5048 if com.is_bool_indexer(key):
#    5049     # if we have list[bools, length=1e5] then doing this check+convert
#    5050     #  takes 166 µs + 2.1 ms and cuts the ndarray.__getitem__
#    5051     #  time below from 3.8 ms to 496 µs
#    5052     # if we already have ndarray[bool], the overhead is 1.4 µs or .25%
#    5053     key = np.asarray(key, dtype=bool)
# -> 5055 result = getitem(key)
#    5056 # Because we ruled out integer above, we always get an arraylike here
# ...

# %%
headway_d['LOW/HIGH']=''

headway_d.loc[headway_d['PERCENT'] >=150, 'LOW/HIGH']= 'high'
headway_d.loc[headway_d['PERCENT'] <=50, 'LOW/HIGH']= 'low'

headway_d
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\3115006755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_d['LOW/HIGH']=''
#             DATE  ROUTE_ABBR  BLOCK_ABBR  OPERATOR  TRIP_ID  \
# 3332  2021-11-01          55        5500      1716   300294
# 3333  2021-11-01          55        5500      1716   300294
# 3334  2021-11-01          55        5500      1716   300294
# 3335  2021-11-01          55        5500      1716   300294
# 3336  2021-11-01          55        5500      1716   300294
# ...          ...         ...         ...       ...      ...
# 4446  2021-11-01          55        5512      1749   300663
# 4447  2021-11-01          55        5512      1749   300663
# ...

# %%
# df.loc[df['column name'] condition, 'new column name'] = 'value if condition is met'

headway_c.loc[headway_c['PERCENT'] >=150, 'LOW/HIGH']= 'high'
headway_c.loc[headway_c['PERCENT'] <=50, 'LOW/HIGH']= 'low'
# Out:
# C:\Users\Rebecca Wolfe\AppData\Local\Temp\ipykernel_41688\1566333776.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   headway_c.loc[headway_c['PERCENT'] >=150, 'LOW/HIGH']= 'high'

# %%
headway_c.loc[headway_c[:,'PERCENT'] >=150, 'LOW/HIGH']= 'high'
headway_c.loc[headway_c[:,'PERCENT'] <=50, 'LOW/HIGH']= 'low'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 'PERCENT')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 headway_c.loc[headway_c[:,'PERCENT'] >=150, 'LOW/HIGH']= 'high'
# ...
